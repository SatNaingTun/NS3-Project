# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader


# -------------------------------------------------------------
# Directories
# -------------------------------------------------------------
DATA_DIR  = "../outputs/datasets/"
MODEL_DIR = "../outputs/models/"
PRED_DIR  = "../outputs/models/predictions/"

os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)


# -------------------------------------------------------------
# Targets & config
# -------------------------------------------------------------
TARGET_MAP = {
    "Throughput": "Perf_Avg_Throughput",
    "Latency":    "Perf_Avg_Latency",
    "Loss":       "Perf_Avg_Loss",
}

EXCLUDE = [
    "StartDateTime", "EndDateTime",
    "Perf_Filename", "ND_Filename",
    "RunDateTime"
]

WINDOW_SIZE = 1          # each row is 1-step sequence
BATCH_SIZE  = 32
EPOCHS      = 60
LR          = 1e-3


# ============================================================
# 1. Load data & extract numeric X/y
# ============================================================

def load_split_data():
    df_train = pd.read_csv(os.path.join(DATA_DIR, "train.csv"))
    df_valid = pd.read_csv(os.path.join(DATA_DIR, "valid.csv"))
    df_test  = pd.read_csv(os.path.join(DATA_DIR, "test.csv"))
    return df_train, df_valid, df_test


def extract_xy(df):
    """
    Independent from external TARGETS variables; very stable.
    """
    df = df.drop(columns=[c for c in EXCLUDE if c in df.columns], errors="ignore")

    df_num = df.select_dtypes(include=[np.number])

    target_cols = list(TARGET_MAP.values())
    feature_cols = [c for c in df_num.columns if c not in target_cols]

    X = df_num[feature_cols].fillna(0).values.astype(np.float32)

    y = {
        "Throughput": df_num[TARGET_MAP["Throughput"]].fillna(0).values.astype(np.float32),
        "Latency":    df_num[TARGET_MAP["Latency"]].fillna(0).values.astype(np.float32),
        "Loss":       df_num[TARGET_MAP["Loss"]].fillna(0).values.astype(np.float32),
    }

    return X, y, feature_cols


# ============================================================
# 2. Sequence generator (robust against tiny datasets)
# ============================================================

def make_sequence_dataset(X, y, window=1):
    """
    Ensures even tiny valid/test splits produce sequences.
    """
    N = len(X)
    if N == 0:
        return np.empty((0, 1, X.shape[1])), np.empty((0,), dtype=np.float32)

    X_seq = X.reshape(N, 1, X.shape[1])  # (N,1,features)
    y_seq = y.copy()
    return X_seq, y_seq


# ============================================================
# 3. GRU Model Definition
# ============================================================

class GRUModel(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_layers=2):
        super().__init__()

        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        self.gru = nn.GRU(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True
        )

        self.fc = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        out, _ = self.gru(x)
        last = out[:, -1, :]        # final timestep
        return self.fc(last)


# ============================================================
# 4. Train a Single GRU
# ============================================================

def train_single_gru(X_train, y_train, X_valid, y_valid, model_name, input_dim):

    device = "cuda" if torch.cuda.is_available() else "cpu"

    model = GRUModel(input_dim).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)
    loss_fn = nn.MSELoss()

    train_ds = TensorDataset(
        torch.tensor(X_train, dtype=torch.float32),
        torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
    )
    valid_ds = TensorDataset(
        torch.tensor(X_valid, dtype=torch.float32),
        torch.tensor(y_valid, dtype=torch.float32).unsqueeze(1)
    )

    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
    valid_loader = DataLoader(valid_ds, batch_size=BATCH_SIZE)

    best_loss = float("inf")
    patience = 0
    patience_limit = 10
    best_state = None

    for epoch in range(EPOCHS):
        # -------------- TRAIN ------------------
        model.train()
        train_loss = 0.0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)

            optimizer.zero_grad()
            pred = model(xb)
            loss = loss_fn(pred, yb)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_loss /= max(1, len(train_loader))

        # -------------- VALID ------------------
        model.eval()
        valid_loss = 0.0
        with torch.no_grad():
            for xb, yb in valid_loader:
                xb, yb = xb.to(device), yb.to(device)
                pred = model(xb)
                valid_loss += loss_fn(pred, yb).item()

        valid_loss /= max(1, len(valid_loader))

        print(f"[GRU-{model_name}] Epoch {epoch+1}/{EPOCHS} | "
              f"Train={train_loss:.4f} | Valid={valid_loss:.4f}")

        # -------------- EARLY STOP --------------
        if valid_loss < best_loss:
            best_loss = valid_loss
            best_state = model.state_dict()
            patience = 0
        else:
            patience += 1
            if patience >= patience_limit:
                print(f"[GRU-{model_name}] Early stopping.")
                break

    if best_state is not None:
        model.load_state_dict(best_state)

    # Save model
    model_path = os.path.join(MODEL_DIR, f"gru_model_{model_name.lower()}.pt")
    torch.save(model.state_dict(), model_path)
    print(f"[GRU-{model_name}] Saved → {model_path}")

    return model


# ============================================================
# 5. Prediction Function
# ============================================================

def predict_gru(model, X):
    device = next(model.parameters()).device
    with torch.no_grad():
        pred = model(torch.tensor(X, dtype=torch.float32).to(device))
    return pred.cpu().numpy().flatten()


# ============================================================
# 6. Full Training Pipeline
# ============================================================

def train_gru_pipeline():

    df_train, df_valid, df_test = load_split_data()

    X_train, y_train_dict, feature_cols = extract_xy(df_train)
    X_valid, y_valid_dict, _           = extract_xy(df_valid)
    X_test,  y_test_dict, _            = extract_xy(df_test)

    input_dim = X_train.shape[1]
    print(f"GRU input_dim = {input_dim}, WINDOW_SIZE = {WINDOW_SIZE}")

    for target_name in ["Throughput", "Latency", "Loss"]:

        print(f"\n=== GRU training for {target_name} ===")

        y_train = y_train_dict[target_name]
        y_valid = y_valid_dict[target_name]
        y_test  = y_test_dict[target_name]

        # Build sequences
        Xtr, ytr = make_sequence_dataset(X_train, y_train, WINDOW_SIZE)
        Xva, yva = make_sequence_dataset(X_valid, y_valid, WINDOW_SIZE)
        Xte, yte = make_sequence_dataset(X_test,  y_test,  WINDOW_SIZE)

        if len(Xtr) == 0:
            print(f"[{target_name}] Skipping — no training samples.")
            continue

        # Train model
        model = train_single_gru(Xtr, ytr, Xva, yva, target_name, input_dim)

        # Predictions
        pred_valid = predict_gru(model, Xva)
        pred_test  = predict_gru(model, Xte)

        # Save predicted vs actual
        pd.DataFrame({"y_true": yva, "y_pred": pred_valid}).to_csv(
            os.path.join(PRED_DIR, f"gru_{target_name}_valid_predictions.csv"),
            index=False
        )
        pd.DataFrame({"y_true": yte, "y_pred": pred_test}).to_csv(
            os.path.join(PRED_DIR, f"gru_{target_name}_test_predictions.csv"),
            index=False
        )

        print(f"[GRU-{target_name}] Saved predictions (valid/test).")


# ============================================================
# 7. Run
# ============================================================

if __name__ == "__main__":
    train_gru_pipeline()
# Out:
# GRU input_dim = 73, WINDOW_SIZE = 1
#
# === GRU training for Throughput ===
# [GRU-Throughput] Epoch 1/60 | Train=0.0820 | Valid=0.0458
# [GRU-Throughput] Epoch 2/60 | Train=0.0423 | Valid=0.0160
# [GRU-Throughput] Epoch 3/60 | Train=0.0159 | Valid=0.0023
# [GRU-Throughput] Epoch 4/60 | Train=0.0035 | Valid=0.0033
# [GRU-Throughput] Epoch 5/60 | Train=0.0012 | Valid=0.0094
# [GRU-Throughput] Epoch 6/60 | Train=0.0060 | Valid=0.0143
# [GRU-Throughput] Epoch 7/60 | Train=0.0102 | Valid=0.0171
# [GRU-Throughput] Epoch 8/60 | Train=0.0129 | Valid=0.0158
# [GRU-Throughput] Epoch 9/60 | Train=0.0135 | Valid=0.0126
# [GRU-Throughput] Epoch 10/60 | Train=0.0121 | Valid=0.0069
# [GRU-Throughput] Epoch 11/60 | Train=0.0090 | Valid=0.0032
# [GRU-Throughput] Epoch 12/60 | Train=0.0055 | Valid=0.0011
# [GRU-Throughput] Epoch 13/60 | Train=0.0025 | Valid=0.0003
# [GRU-Throughput] Epoch 14/60 | Train=0.0007 | Valid=0.0004
# [GRU-Throughput] Epoch 15/60 | Train=0.0005 | Valid=0.0017
# [GRU-Throughput] Epoch 16/60 | Train=0.0009 | Valid=0.0041
# [GRU-Throughput] Epoch 17/60 | Train=0.0020 | Valid=0.0061
# [GRU-Throughput] Epoch 18/60 | Train=0.0029 | Valid=0.0071
# [GRU-Throughput] Epoch 19/60 | Train=0.0035 | Valid=0.0072
# [GRU-Throughput] Epoch 20/60 | Train=0.0039 | Valid=0.0065
# [GRU-Throughput] Epoch 21/60 | Train=0.0036 | Valid=0.0054
# [GRU-Throughput] Epoch 22/60 | Train=0.0030 | Valid=0.0041
# [GRU-Throughput] Epoch 23/60 | Train=0.0021 | Valid=0.0028
# [GRU-Throughput] Early stopping.
# [GRU-Throughput] Saved → ../outputs/models/gru_model_throughput.pt
# [GRU-Throughput] Saved predictions (valid/test).
#
# === GRU training for Latency ===
# [GRU-Latency] Epoch 1/60 | Train=14.2193 | Valid=5.9331
# [GRU-Latency] Epoch 2/60 | Train=13.6405 | Valid=5.5870
# [GRU-Latency] Epoch 3/60 | Train=13.1278 | Valid=5.2457
# [GRU-Latency] Epoch 4/60 | Train=12.6353 | Valid=4.9096
# [GRU-Latency] Epoch 5/60 | Train=12.1508 | Valid=4.5926
# [GRU-Latency] Epoch 6/60 | Train=11.6487 | Valid=4.2859
# [GRU-Latency] Epoch 7/60 | Train=11.1754 | Valid=3.9815
# [GRU-Latency] Epoch 8/60 | Train=10.7112 | Valid=3.6738
# [GRU-Latency] Epoch 9/60 | Train=10.2544 | Valid=3.3801
# [GRU-Latency] Epoch 10/60 | Train=9.8041 | Valid=3.0722
# [GRU-Latency] Epoch 11/60 | Train=9.3714 | Valid=2.7676
# [GRU-Latency] Epoch 12/60 | Train=8.9465 | Valid=2.5035
# [GRU-Latency] Epoch 13/60 | Train=8.5244 | Valid=2.2563
# [GRU-Latency] Epoch 14/60 | Train=8.1060 | Valid=2.0198
# [GRU-Latency] Epoch 15/60 | Train=7.7022 | Valid=1.7846
# [GRU-Latency] Epoch 16/60 | Train=7.2979 | Valid=1.5683
# [GRU-Latency] Epoch 17/60 | Train=6.9184 | Valid=1.3662
# [GRU-Latency] Epoch 18/60 | Train=6.5469 | Valid=1.1766
# [GRU-Latency] Epoch 19/60 | Train=6.1902 | Valid=1.0002
# [GRU-Latency] Epoch 20/60 | Train=5.8449 | Valid=0.8372
# [GRU-Latency] Epoch 21/60 | Train=5.5118 | Valid=0.6880
# [GRU-Latency] Epoch 22/60 | Train=5.1915 | Valid=0.5531
# [GRU-Latency] Epoch 23/60 | Train=4.8845 | Valid=0.4327
# [GRU-Latency] Epoch 24/60 | Train=4.5912 | Valid=0.3269
# [GRU-Latency] Epoch 25/60 | Train=4.3117 | Valid=0.2345
# [GRU-Latency] Epoch 26/60 | Train=4.0395 | Valid=0.1556
# [GRU-Latency] Epoch 27/60 | Train=3.7830 | Valid=0.0953
# [GRU-Latency] Epoch 28/60 | Train=3.5467 | Valid=0.0502
# [GRU-Latency] Epoch 29/60 | Train=3.3273 | Valid=0.0198
# [GRU-Latency] Epoch 30/60 | Train=3.1195 | Valid=0.0037
# [GRU-Latency] Epoch 31/60 | Train=2.9172 | Valid=0.0019
# [GRU-Latency] Epoch 32/60 | Train=2.7417 | Valid=0.0135
# [GRU-Latency] Epoch 33/60 | Train=2.5644 | Valid=0.0415
# [GRU-Latency] Epoch 34/60 | Train=2.4057 | Valid=0.0802
# [GRU-Latency] Epoch 35/60 | Train=2.2834 | Valid=0.1296
# [GRU-Latency] Epoch 36/60 | Train=2.1753 | Valid=0.1895
# [GRU-Latency] Epoch 37/60 | Train=2.0813 | Valid=0.2586
# [GRU-Latency] Epoch 38/60 | Train=2.0008 | Valid=0.3357
# [GRU-Latency] Epoch 39/60 | Train=1.9326 | Valid=0.4194
# [GRU-Latency] Epoch 40/60 | Train=1.8730 | Valid=0.5084
# [GRU-Latency] Epoch 41/60 | Train=1.8250 | Valid=0.6012
# [GRU-Latency] Early stopping.
# [GRU-Latency] Saved → ../outputs/models/gru_model_latency.pt
# [GRU-Latency] Saved predictions (valid/test).
#
# === GRU training for Loss ===
# [GRU-Loss] Epoch 1/60 | Train=9353.4883 | Valid=9318.4033
# [GRU-Loss] Epoch 2/60 | Train=9334.1562 | Valid=9298.3223
# [GRU-Loss] Epoch 3/60 | Train=9314.7305 | Valid=9279.4121
# [GRU-Loss] Epoch 4/60 | Train=9297.4170 | Valid=9261.9863
# [GRU-Loss] Epoch 5/60 | Train=9280.0322 | Valid=9244.0059
# [GRU-Loss] Epoch 6/60 | Train=9262.9248 | Valid=9226.2207
# [GRU-Loss] Epoch 7/60 | Train=9245.3584 | Valid=9208.5449
# [GRU-Loss] Epoch 8/60 | Train=9227.9902 | Valid=9190.9365
# [GRU-Loss] Epoch 9/60 | Train=9210.7686 | Valid=9173.0986
# [GRU-Loss] Epoch 10/60 | Train=9193.3262 | Valid=9154.8916
# [GRU-Loss] Epoch 11/60 | Train=9175.6182 | Valid=9136.1289
# [GRU-Loss] Epoch 12/60 | Train=9157.7354 | Valid=9116.0703
# [GRU-Loss] Epoch 13/60 | Train=9139.2734 | Valid=9097.1299
# [GRU-Loss] Epoch 14/60 | Train=9120.5664 | Valid=9077.8320
# [GRU-Loss] Epoch 15/60 | Train=9100.7578 | Valid=9058.1328
# [GRU-Loss] Epoch 16/60 | Train=9080.2090 | Valid=9038.5586
# [GRU-Loss] Epoch 17/60 | Train=9060.7617 | Valid=9018.7842
# [GRU-Loss] Epoch 18/60 | Train=9040.6807 | Valid=8998.8184
# [GRU-Loss] Epoch 19/60 | Train=9020.8555 | Valid=8975.5332
# [GRU-Loss] Epoch 20/60 | Train=8999.4062 | Valid=8954.8760
# [GRU-Loss] Epoch 21/60 | Train=8979.2363 | Valid=8934.0459
# [GRU-Loss] Epoch 22/60 | Train=8958.4277 | Valid=8912.7559
# [GRU-Loss] Epoch 23/60 | Train=8937.1719 | Valid=8891.7051
# [GRU-Loss] Epoch 24/60 | Train=8916.3584 | Valid=8870.5381
# [GRU-Loss] Epoch 25/60 | Train=8895.4746 | Valid=8849.2422
# [GRU-Loss] Epoch 26/60 | Train=8874.4219 | Valid=8827.8232
# [GRU-Loss] Epoch 27/60 | Train=8853.2090 | Valid=8806.2910
# [GRU-Loss] Epoch 28/60 | Train=8831.7773 | Valid=8784.6348
# [GRU-Loss] Epoch 29/60 | Train=8810.2578 | Valid=8762.7588
# [GRU-Loss] Epoch 30/60 | Train=8788.7275 | Valid=8740.2900
# [GRU-Loss] Epoch 31/60 | Train=8767.0059 | Valid=8717.2939
# [GRU-Loss] Epoch 32/60 | Train=8745.0352 | Valid=8694.8145
# [GRU-Loss] Epoch 33/60 | Train=8723.1484 | Valid=8672.6719
# [GRU-Loss] Epoch 34/60 | Train=8701.3193 | Valid=8650.4873
# [GRU-Loss] Epoch 35/60 | Train=8679.4229 | Valid=8628.2559
# [GRU-Loss] Epoch 36/60 | Train=8657.4619 | Valid=8605.9834
# [GRU-Loss] Epoch 37/60 | Train=8635.4463 | Valid=8583.6748
# [GRU-Loss] Epoch 38/60 | Train=8613.3809 | Valid=8561.3359
# [GRU-Loss] Epoch 39/60 | Train=8591.2686 | Valid=8538.9756
# [GRU-Loss] Epoch 40/60 | Train=8569.1182 | Valid=8516.5996
# [GRU-Loss] Epoch 41/60 | Train=8546.9414 | Valid=8494.2100
# [GRU-Loss] Epoch 42/60 | Train=8524.7363 | Valid=8471.8184
# [GRU-Loss] Epoch 43/60 | Train=8502.5146 | Valid=8449.4268
# [GRU-Loss] Epoch 44/60 | Train=8480.2773 | Valid=8427.0430
# [GRU-Loss] Epoch 45/60 | Train=8458.0176 | Valid=8404.6709
# [GRU-Loss] Epoch 46/60 | Train=8435.4912 | Valid=8382.2832
# [GRU-Loss] Epoch 47/60 | Train=8412.8174 | Valid=8358.4336
# [GRU-Loss] Epoch 48/60 | Train=8389.8301 | Valid=8332.5068
# [GRU-Loss] Epoch 49/60 | Train=8366.7295 | Valid=8306.5010
# [GRU-Loss] Epoch 50/60 | Train=8341.0342 | Valid=8282.3867
# [GRU-Loss] Epoch 51/60 | Train=8316.9805 | Valid=8260.0244
# [GRU-Loss] Epoch 52/60 | Train=8292.7549 | Valid=8237.7227
# [GRU-Loss] Epoch 53/60 | Train=8270.0586 | Valid=8215.4902
# [GRU-Loss] Epoch 54/60 | Train=8247.8672 | Valid=8193.3340
# [GRU-Loss] Epoch 55/60 | Train=8225.7402 | Valid=8171.2646
# [GRU-Loss] Epoch 56/60 | Train=8203.6904 | Valid=8149.2954
# [GRU-Loss] Epoch 57/60 | Train=8181.7261 | Valid=8127.4287
# [GRU-Loss] Epoch 58/60 | Train=8159.8564 | Valid=8105.6768
# [GRU-Loss] Epoch 59/60 | Train=8138.0908 | Valid=8084.0479
# [GRU-Loss] Epoch 60/60 | Train=8116.4365 | Valid=8062.5459
# [GRU-Loss] Saved → ../outputs/models/gru_model_loss.pt
# [GRU-Loss] Saved predictions (valid/test).

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

PLOT_DIR = "../outputs/models/plots/"
PRED_DIR = "../outputs/models/predictions/"
os.makedirs(PLOT_DIR, exist_ok=True)

TARGETS = ["Throughput", "Latency", "Loss"]

plt.style.use("seaborn-v0_8-whitegrid")


# ============================================================
# Load prediction files
# ============================================================

def load_gru_predictions(metric, split):
    """
    Loads GRU prediction CSV files generated by gru_training.py
    """
    path = os.path.join(PRED_DIR, f"gru_{metric}_{split}_predictions.csv")

    if not os.path.exists(path):
        raise FileNotFoundError(f"Missing GRU prediction file: {path}")

    df = pd.read_csv(path)
    return df["y_true"], df["y_pred"]


# ============================================================
# Predicted vs Actual scatterplot
# ============================================================

def plot_pred_vs_actual(y_true, y_pred, title, outfile, showImage=False):

    plt.figure(figsize=(7, 6))
    sns.scatterplot(x=y_true, y=y_pred, alpha=0.6)

    # Identity line
    lo = min(y_true.min(), y_pred.min())
    hi = max(y_true.max(), y_pred.max())
    plt.plot([lo, hi], [lo, hi], "r--", linewidth=2, label="Ideal")

    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.title(title)
    plt.legend()
    plt.tight_layout()

    plt.savefig(outfile, dpi=300)
    print(f"Saved → {outfile}")

    if showImage:
        plt.show()
    else:
        plt.close()


# ============================================================
# Time-series plot
# ============================================================

def plot_time_series(y_true, y_pred, title, outfile, showImage=False):

    plt.figure(figsize=(12, 5))
    plt.plot(y_true.values, label="Actual", linewidth=2)
    plt.plot(y_pred, linestyle="--", label="Predicted", linewidth=2)

    plt.xlabel("Sample Index")
    plt.ylabel("Value")
    plt.title(title)
    plt.legend()
    plt.tight_layout()

    plt.savefig(outfile, dpi=300)
    print(f"Saved → {outfile}")

    if showImage:
        plt.show()
    else:
        plt.close()


# ============================================================
# Generate all GRU plots
# ============================================================

def generate_gru_plots(showImage=False):

    for metric in TARGETS:

        print(f"\n=== Generating GRU plots for {metric} ===")

        # ---------------------------
        # VALIDATION PLOTS
        # ---------------------------
        try:
            yv, pv = load_gru_predictions(metric, "valid")

            plot_pred_vs_actual(
                yv, pv,
                title=f"GRU – Predicted vs Actual ({metric}, Validation)",
                outfile=os.path.join(PLOT_DIR, f"gru_{metric}_pred_valid.png"),
                showImage=showImage
            )

            plot_time_series(
                yv, pv,
                title=f"GRU – Time Series ({metric}, Validation)",
                outfile=os.path.join(PLOT_DIR, f"gru_{metric}_ts_valid.png"),
                showImage=showImage
            )

        except FileNotFoundError:
            print(f"[WARNING] No validation predictions for GRU-{metric}")

        # ---------------------------
        # TEST PLOTS
        # ---------------------------
        try:
            yt, pt = load_gru_predictions(metric, "test")

            plot_pred_vs_actual(
                yt, pt,
                title=f"GRU – Predicted vs Actual ({metric}, Test)",
                outfile=os.path.join(PLOT_DIR, f"gru_{metric}_pred_test.png"),
                showImage=showImage
            )

            plot_time_series(
                yt, pt,
                title=f"GRU – Time Series ({metric}, Test)",
                outfile=os.path.join(PLOT_DIR, f"gru_{metric}_ts_test.png"),
                showImage=showImage
            )

        except FileNotFoundError:
            print(f"[WARNING] No test predictions for GRU-{metric}")

    print("\nGRU plots generated successfully!")

# %%
# from gru_plots import generate_gru_plots
generate_gru_plots(showImage=True)
# Out:
# === Generating GRU plots for Throughput ===
# Saved → ../outputs/models/plots/gru_Throughput_pred_valid.png
# Saved → ../outputs/models/plots/gru_Throughput_ts_valid.png
# Saved → ../outputs/models/plots/gru_Throughput_pred_test.png
# Saved → ../outputs/models/plots/gru_Throughput_ts_test.png
# === Generating GRU plots for Latency ===
# Saved → ../outputs/models/plots/gru_Latency_pred_valid.png
# Saved → ../outputs/models/plots/gru_Latency_ts_valid.png
# Saved → ../outputs/models/plots/gru_Latency_pred_test.png
# Saved → ../outputs/models/plots/gru_Latency_ts_test.png
# === Generating GRU plots for Loss ===
# Saved → ../outputs/models/plots/gru_Loss_pred_valid.png
# Saved → ../outputs/models/plots/gru_Loss_ts_valid.png
# Saved → ../outputs/models/plots/gru_Loss_pred_test.png
# Saved → ../outputs/models/plots/gru_Loss_ts_test.png
# GRU plots generated successfully!

# %%
import os
import time
import torch
import torch.nn as nn
import numpy as np


# ============================================================
# 1. GRU Model (must match your training architecture)
# ============================================================

class GRUModel(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_layers=2):
        super().__init__()

        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        self.gru = nn.GRU(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True
        )

        self.fc = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        out, _ = self.gru(x)
        last = out[:, -1, :]
        return self.fc(last)


# ============================================================
# 2. Load GRU model weights
# ============================================================

def load_gru_model(model_path):
    """
    Load GRU model and infer input_dim from checkpoint.
    """
    state = torch.load(model_path, map_location="cpu")

    # Infer input_dim from GRU input-hidden weight
    # weight_ih_l0 shape: (3*H, input_dim)
    input_dim = state["gru.weight_ih_l0"].shape[1]

    model = GRUModel(input_dim)
    model.load_state_dict(state)
    model.eval()

    return model, input_dim



# ============================================================
# 3. Parameter count + Model size
# ============================================================

def count_parameters(model):
    return sum(p.numel() for p in model.parameters())


def model_size_bytes(model):
    return count_parameters(model) * 4     # FP32 → 4 bytes / param


# ============================================================
# 4. FLOPs calculation for GRU
# ============================================================

def compute_gru_flops(model, sequence_len=1):
    """
    GRU FLOPs:

    GRU cell equations:
        r = σ(Wr*x + Ur*h + br)
        z = σ(Wz*x + Uz*h + bz)
        h~ = tanh(Wh*x + Uh*(r ⊙ h) + bh)
        h_new = (1-z)⊙h + z⊙h~

    FLOPs per GRU cell per timestep:
        FLOPs = 3 * [H*(I + H + 1)]  (3 gates)

    For L layers & T timesteps:
        FLOPs_total = L * T * FLOPs_cell

    FC layer:
        FLOPs_fc = 2 * H
    """

    I = model.input_dim
    H = model.hidden_dim
    L = model.num_layers

    # GRU single layer FLOPs per timestep
    flops_cell = 3 * H * (I + H + 1)

    # All layers × timesteps
    flops_gru = L * sequence_len * flops_cell

    # Final FC layer
    flops_fc = 2 * H

    return flops_gru + flops_fc


# ============================================================
# 5. Latency measurement
# ============================================================

def measure_latency(model, example_input, runs=200, warmup=20):

    device = "cpu"
    model.to(device)
    example_input = example_input.to(device)

    # Warmup (avoid first-run overhead)
    with torch.no_grad():
        for _ in range(warmup):
            _ = model(example_input)

    # Timed loop
    t0 = time.perf_counter()
    with torch.no_grad():
        for _ in range(runs):
            _ = model(example_input)
    t1 = time.perf_counter()

    return (t1 - t0) / runs


# ============================================================
# 6. Estimated energy
# ============================================================

def estimate_energy(latency_s, power_W=2.0):
    return latency_s * power_W


# ============================================================
# 7. Peak activation memory
# ============================================================

def estimate_peak_activation_memory(model, example_input):
    with torch.no_grad():
        out = model(example_input)
    return out.numel() * 4     # FP32


# ============================================================
# 8. Full GRU edge evaluation
# ============================================================

def evaluate_gru_edge(model_path, sequence_len=1, assumed_power_W=2.0):

    model, input_dim = load_gru_model(model_path)

    example_input = torch.randn(1, sequence_len, input_dim)

    params = count_parameters(model)
    size_b = model_size_bytes(model)
    size_mb = size_b / (1024 * 1024)

    flops = compute_gru_flops(model, sequence_len)
    latency_s = measure_latency(model, example_input)
    latency_ms = latency_s * 1000

    energy = estimate_energy(latency_s, assumed_power_W)
    peak_mem = estimate_peak_activation_memory(model, example_input)

    return {
        "Input Dim": input_dim,
        "Parameters": params,
        "Model Size (Bytes)": size_b,
        "Model Size (MB)": size_mb,
        "FLOPs": flops,
        "Latency (s)": latency_s,
        "Latency (ms)": latency_ms,
        "Energy Estimated (J)": energy,
        "Peak Activation Memory (Bytes)": peak_mem
    }

# %%
# from gru_edge_evaluation import evaluate_gru_edge

# input_dim = 103
model_path = "../outputs/models/gru_model_throughput.pt"

metrics = evaluate_gru_edge(model_path,  sequence_len=1)

for k, v in metrics.items():
    print(f"{k}: {v}")
# Out:
# Input Dim: 73
# Parameters: 51713
# Model Size (Bytes): 206852
# Model Size (MB): 0.19726943969726562
# FLOPs: 53120
# Latency (s): 0.00036289488500187875
# Latency (ms): 0.3628948850018787
# Energy Estimated (J): 0.0007257897700037575
# Peak Activation Memory (Bytes): 4
