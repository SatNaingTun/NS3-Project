# %% [markdown]
# # Wi-Fi Random Topology Simulation Analysis
#
# This Jupyter Notebook analyzes NS-3 simulation results for a **Wi-Fi Random Topology** scenario.
# It visualizes throughput, RSSI, and loss patterns, and summarizes performance degradation due to interference.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the CSV files (adjust paths if necessary)
perf_df = pd.read_csv("../outputs/wifi-random-perf.csv")
rssi_df = pd.read_csv("../outputs/wifi-random-rssi.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Load the CSV files (adjust paths if necessary)
# ----> 2 perf_df = pd.read_csv("../outputs/wifi-random-perf.csv")
#       3 rssi_df = pd.read_csv("../outputs/wifi-random-rssi.csv")
#
# File e:\AIT_Projects\NS3-Project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File e:\AIT_Projects\NS3-Project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File e:\AIT_Projects\NS3-Project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File e:\AIT_Projects\NS3-Project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File e:\AIT_Projects\NS3-Project\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../outputs/wifi-random-perf.csv'

# %%
# Clean column names
perf_df.columns = [c.strip() for c in perf_df.columns]
rssi_df.columns = [c.strip() for c in rssi_df.columns]

# %%
perf_df.head()
# Out:
#    FlowID    Source Destination  Throughput(Mbps)  Latency_avg(ms)  \
# 0       1  10.1.4.1    10.1.4.3          0.000000          0.00000
# 1       2  10.1.4.2    10.1.4.3          0.000000          0.00000
# 2       3  10.1.3.1    10.1.3.8          0.845912         19.74720
# 3       4  10.1.3.2    10.1.3.8          0.018282          2.57143
# 4       5  10.1.3.3    10.1.3.8          0.000000          0.00000
#
#    Jitter_avg(ms)  PacketLoss(%)
# 0         0.00000       100.0000
# 1         0.00000       100.0000
# 2         6.60006        99.8929
# 3         2.59898        98.9643
# 4         0.00000       100.0000

# %%
# === Figure 1: Flow Throughput per Flow ID ===
plt.figure(figsize=(8,4))
plt.bar(perf_df["FlowID"], perf_df["Throughput(Mbps)"], color="steelblue")
plt.title("Flow Throughput (Mbps) per Flow ID")
plt.xlabel("Flow ID")
plt.ylabel("Throughput (Mbps)")
plt.title("Flow Throughput (Mbps) per Flow ID")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# plt.savefig("plot_throughput.png")  # Uncomment to save

# %%
# === Figure 2: RSSI vs Time ===
plt.figure(figsize=(8,4))
plt.plot(rssi_df["time_s"], rssi_df["signal_dBm"], label="Signal (dBm)")
plt.plot(rssi_df["time_s"], rssi_df["noise_dBm"], label="Noise (dBm)")
plt.title("RSSI vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Power (dBm)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# plt.savefig("plot_rssi.png")

# %%
# === Figure 3: Packet Loss vs Throughput ===
plt.figure(figsize=(8,4))
plt.scatter(perf_df["Throughput(Mbps)"], perf_df["PacketLoss(%)"], color="red")
plt.title("Packet Loss vs Throughput per Flow")
plt.xlabel("Throughput (Mbps)")
plt.ylabel("Packet Loss (%)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# plt.savefig("plot_loss_vs_throughput.png")

# %%
# === Figure 4: Signal Strength over Time vs Average Throughput ===
rssi_df_sorted = rssi_df.sort_values("time_s")
rssi_df_sorted["signal_avg"] = rssi_df_sorted["signal_dBm"].rolling(window=20, min_periods=1).mean()
avg_throughput = perf_df["Throughput(Mbps)"].mean()

plt.figure(figsize=(8,4))
plt.plot(rssi_df_sorted["time_s"], rssi_df_sorted["signal_avg"], label="Signal (dBm)", color="blue")
plt.axhline(y=rssi_df_sorted["signal_avg"].mean(), color="cyan", linestyle="--", label="Avg Signal")
plt.axhline(y=avg_throughput - 100, color="red", linestyle=":", label=f"Scaled Avg Throughput ({avg_throughput:.2f} Mbps)")
plt.title("Signal Strength over Time vs. Average Throughput Reference")
plt.xlabel("Time (s)")
plt.ylabel("Signal Power (dBm)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# plt.savefig("plot_timeline.png")

# %%
# === Figure 5: Flow Performance Heatmap ===
heatmap_data = perf_df.pivot_table(index="Source", values=["Throughput(Mbps)", "PacketLoss(%)"], aggfunc="mean")
heatmap_data["Throughput_norm"] = heatmap_data["Throughput(Mbps)"] / max(heatmap_data["Throughput(Mbps)"].max(), 1e-6)

plt.figure(figsize=(7,4))
sns.heatmap(
    heatmap_data[["Throughput_norm"]],
    annot=heatmap_data[["PacketLoss(%)"]],
    fmt=".1f",
    cmap="YlGnBu",
    cbar_kws={"label": "Normalized Throughput (0–1)"}
)
plt.title("Flow Performance Heatmap (Packet Loss % annotated)")
plt.tight_layout()
plt.show()

# %%
# plt.savefig("plot_heatmap.png")

# %%
# === Performance Summary Table ===
def interpret_flow(row):
    if row["Throughput(Mbps)"] < 0.1:
        return "Inactive or heavily interfered link"
    elif row["PacketLoss(%)"] > 95:
        return "Severe congestion/interference"
    elif row["PacketLoss(%)"] > 80:
        return "High packet loss, unstable link"
    elif row["Throughput(Mbps)"] > 0.5 and row["PacketLoss(%)"] < 80:
        return "Moderate performance under contention"
    else:
        return "Acceptable but limited link"

summary_df = perf_df.copy()
summary_df["Interpretation"] = summary_df.apply(interpret_flow, axis=1)
summary_df
# Out:
#    FlowID    Source Destination  Throughput(Mbps)  Latency_avg(ms)  \
# 0       1  10.1.4.1    10.1.4.3          0.000000          0.00000
# 1       2  10.1.4.2    10.1.4.3          0.000000          0.00000
# 2       3  10.1.3.1    10.1.3.8          0.845912         19.74720
# 3       4  10.1.3.2    10.1.3.8          0.018282          2.57143
# 4       5  10.1.3.3    10.1.3.8          0.000000          0.00000
# 5       6  10.1.3.4    10.1.3.8          0.000000          0.00000
# 6       7  10.1.3.5    10.1.3.8          0.098178          3.58564
# 7       8  10.1.3.6    10.1.3.8          0.852064          1.37983
# 8       9  10.1.3.7    10.1.3.8          0.015629          2.61114
#
#    Jitter_avg(ms)  PacketLoss(%)                       Interpretation
# 0         0.00000       100.0000  Inactive or heavily interfered link
# 1         0.00000       100.0000  Inactive or heavily interfered link
# 2         6.60006        99.8929       Severe congestion/interference
# 3         2.59898        98.9643  Inactive or heavily interfered link
# 4         0.00000       100.0000  Inactive or heavily interfered link
# 5         0.00000       100.0000  Inactive or heavily interfered link
# 6         4.10745        99.5000  Inactive or heavily interfered link
# 7         1.67202        97.3571       Severe congestion/interference
# 8         2.96595        99.5357  Inactive or heavily interfered link

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))

# ---- Left plot: Throughput vs FlowID ----
axes[0].plot(perf_df["FlowID"], perf_df["Throughput(Mbps)"],
             marker="o", linewidth=2, color="royalblue")
axes[0].set_title("Throughput vs FlowID", fontsize=12)
axes[0].set_xlabel("Flow ID", fontsize=10)
axes[0].set_ylabel("Throughput (Mbps)", fontsize=10)
axes[0].grid(True, linestyle="--", alpha=0.6)

# ---- Right plot: RSSI vs Time ----
axes[1].plot(rssi_df["time_s"], rssi_df["signal_dBm"],
             marker="s", linewidth=1.8, color="darkorange")
axes[1].set_title("Signal Strength (RSSI) vs Time", fontsize=12)
axes[1].set_xlabel("Time (s)", fontsize=10)
axes[1].set_ylabel("Signal Strength (dBm)", fontsize=10)
axes[1].grid(True, linestyle="--", alpha=0.6)

# ---- Global layout & save ----
fig.suptitle("Preliminary Simulation Analysis (NS-3 Results)", fontsize=13, fontweight="bold")
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

save_path = "../figures/Slide29_NS3_Combined.png"
plt.savefig(save_path, dpi=300)
plt.show()
